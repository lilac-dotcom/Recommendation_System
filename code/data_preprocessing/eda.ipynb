# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# loading the dataset
dataset_path = "C:\qandeel\projects\Recommendation_System\data\songs_data\data.csv"
df = pd.read_csv(dataset_path)

# %%
# displaying the dataset
print(df)
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0              0       0.01020         0.833       204600   0.434
# 1              1       0.19900         0.743       326933   0.359
# 2              2       0.03440         0.838       185707   0.412
# 3              3       0.60400         0.494       199413   0.338
# 4              4       0.18000         0.678       392893   0.561
# ...          ...           ...           ...          ...     ...
# 2012        2012       0.00106         0.584       274404   0.932
# 2013        2013       0.08770         0.894       182182   0.892
# 2014        2014       0.00857         0.637       207200   0.935
# 2015        2015       0.00164         0.557       185600   0.992
# 2016        2016       0.00281         0.446       204520   0.915
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0             0.021900    2    0.1650    -8.795     1       0.4310  150.062
# ...

# %%
# using pandas isnull() to find missing values in the dataset
missing_data = df.isnull()
print(missing_data)
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0          False         False         False        False   False
# 1          False         False         False        False   False
# 2          False         False         False        False   False
# 3          False         False         False        False   False
# 4          False         False         False        False   False
# ...          ...           ...           ...          ...     ...
# 2012       False         False         False        False   False
# 2013       False         False         False        False   False
# 2014       False         False         False        False   False
# 2015       False         False         False        False   False
# 2016       False         False         False        False   False
#
#       instrumentalness    key  liveness  loudness   mode  speechiness  tempo  \
# 0                False  False     False     False  False        False  False
# ...

# %%
# from the above, it seems as if there are no missing values. however we can confirm;
count_missing_data = df.isnull().sum()
print(count_missing_data)

# in the output, unnamed: 0 refers to the index column
# Out:
# Unnamed: 0          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# target              0
# song_title          0
# artist              0
# dtype: int64

# %%
''' the output above shows us that there are no missing data points in the dataset. so we move on.
next we need to identify potential outliers in numeric columns (e.g., acousticness) that could affect model performance.'''

# starting with the first column, 𝗮𝗰𝗼𝘂𝘀𝘁𝗶𝗰𝗻𝗲𝘀𝘀.

''' 
what is 𝗮𝗰𝗼𝘂𝘀𝘁𝗶𝗰𝗻𝗲𝘀𝘀? according to Spotify for developer's documentation, acousticness is 
"A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic." 
according to classical-music.com, a track being acoustic means 'without electrical amplification'. for example an acoustic guitar 
compared to an electric guitar.
it is a floating point number.

'''

# creating a new figure
fig = plt.figure(figsize =(10, 7))

# creating a boxplot for acousticness
acousticness_df = df["acousticness"]
plt.boxplot(acousticness_df)

# displaying the boxplot
plt.show()

# %%
# due to the vast majority of outliers/fliers on the upper end with the data points increasing in small intervals, there seems to be no anomalies.
# it is entirely possible for various songs to have various amounts of acousticness, furthermore the pattern the outliers have indicates that it
# nothing is out of the ordinary.

# moving on with the next column, danceability

# creating a new figure
fig = plt.figure(figsize =(10, 7))

# creating a boxplot for danceability
danceability_df = df["danceability"]
plt.boxplot(danceability_df)

# displaying the boxplot
plt.show()

# %%
# moving on with the next column, duration_ms

# creating a new figure
fig = plt.figure(figsize =(10, 7))

# creating a boxplot for duration_ms
duration_ms_df = df["duration_ms"]
plt.boxplot(duration_ms_df)

# displaying the boxplot
plt.show()

# %%
# moving on with the next column, energy

# creating a new figure
fig = plt.figure(figsize =(10, 7))

# creating a boxplot for energy
energy_df = df["energy"]
plt.boxplot(energy_df)

# displaying the boxplot
plt.show()

# %%
# moving on with the next column, instrumentalness

# creating a new figure
fig = plt.figure(figsize =(10, 7))

# creating a boxplot for instrumentalness
instrumentalness_df = df["instrumentalness"]
plt.boxplot(instrumentalness_df)

# displaying the boxplot
plt.show()

# %%
# moving on with the next column, key

# creating a new figure
fig = plt.figure(figsize =(10, 7))

# creating a boxplot for key
key_df = df["key"]
plt.boxplot(key_df)

# displaying the boxplot
plt.show()

# %%
# moving on with the next column, liveness

# creating a new figure
fig = plt.figure(figsize =(10, 7))

# creating a boxplot for liveness
liveness_df = df["liveness"]
plt.boxplot(liveness_df)

# displaying the boxplot
plt.show()

# %%
# moving on with the next column, loudness

# creating a new figure
fig = plt.figure(figsize =(10, 7))

# creating a boxplot for loudness
loudness_df = df["loudness"]
plt.boxplot(loudness_df)

# displaying the boxplot
plt.show()

# %%
# moving on with the next column, mode

# creating a new figure
fig = plt.figure(figsize =(10, 7))

# creating a boxplot for mode
mode_df = df["mode"]
plt.boxplot(mode_df)

# displaying the boxplot
plt.show()

# %%
# moving on with the next column, speechiness

# creating a new figure
fig = plt.figure(figsize =(10, 7))

# creating a boxplot for speechiness
speechiness_df = df["speechiness"]
plt.boxplot(speechiness_df)

# displaying the boxplot
plt.show()

# %%
# moving on with the next column, tempo

# creating a new figure
fig = plt.figure(figsize =(10, 7))

# creating a boxplot for tempo
tempo_df = df["tempo"]
plt.boxplot(tempo_df)

# displaying the boxplot
plt.show()

# %%
# moving on with the next column, time_signature

# creating a new figure
fig = plt.figure(figsize =(10, 7))

# creating a boxplot for time_signature
time_signature_df = df["time_signature"]
plt.boxplot(time_signature_df)

# displaying the boxplot
plt.show()

# %%
# moving on with the next column, valence

# creating a new figure
fig = plt.figure(figsize =(10, 7))

# creating a boxplot for valence
valence_df = df["valence"]
plt.boxplot(valence_df)

# displaying the boxplot
plt.show()
